# %%
#Example of Knowledge Representation in KBS
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name}, {self.age} years old"

class KnowledgeBase:
    def __init__(self):
        self.people = []

    def add_person(self, person):
        self.people.append(person)

    def find_person_by_name(self, name):
        for person in self.people:
            if person.name == name:
                return person
        return None 

if __name__ == "__main__":
    kb = KnowledgeBase()
    kb.add_person(Person("Alice", 30))

    person = kb.find_person_by_name("Alice")
    if person:
        print(person)
    else:
        print("Person not found")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 24
#      20                 return person
#      21             return None
#      22
#      23 if __name__ == "__main__":  kb = KnowledgeBase()
# ---> 24 kb.add_person(Person("Alice", 30))
#      25
#      26 person = kb.find_person_by_name("Alice")
#      27 if person:
#
# TypeError: Person() takes no arguments
